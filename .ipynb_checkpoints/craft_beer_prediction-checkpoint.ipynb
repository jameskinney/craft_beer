# %% [markdown]
# # Craft Beer Prediction Model

# %% [markdown]
# For this project, I will be taking a dataset of canned craft beers and using it to predict the Alcohol By Volume (ABV) by finding the best model.
#
# The dataset I will be using has the following columns:
#
# abv: Alcohol by Volume. This is the dependent variable I will be predicting
# ibu: International Bitterness Units: how bitter the beer is
# id: Unique ID for each beer
# name: The name of the beer
# style: The style of beer
# brewery_id: The ID of the brewery corresponding to the brewery.csv
# ounces: How many ounces of beer is sold in the can/bottle

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %% [markdown]
# ## Exploratory Data Analysis

# %%
beers=pd.read_csv('beers.csv')
beers.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
beers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
# Unnamed: 0    2410 non-null int64
# abv           2348 non-null float64
# ibu           1405 non-null float64
# id            2410 non-null int64
# name          2410 non-null object
# style         2405 non-null object
# brewery_id    2410 non-null int64
# ounces        2410 non-null float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 150.7+ KB

# %%
beers.describe()
# Out:
#         Unnamed: 0          abv          ibu           id   brewery_id  \
# count  2410.000000  2348.000000  1405.000000  2410.000000  2410.000000
# mean   1204.500000     0.059773    42.713167  1431.113278   231.749793
# std     695.851397     0.013542    25.954066   752.459975   157.685604
# min       0.000000     0.001000     4.000000     1.000000     0.000000
# 25%     602.250000     0.050000    21.000000   808.250000    93.000000
# 50%    1204.500000     0.056000    35.000000  1453.500000   205.000000
# 75%    1806.750000     0.067000    64.000000  2075.750000   366.000000
# max    2409.000000     0.128000   138.000000  2692.000000   557.000000
#
#             ounces
# count  2410.000000
# mean     13.592241
# std       2.352204
# min       8.400000
# 25%      12.000000
# 50%      12.000000
# 75%      16.000000
# max      32.000000

# %%
# We don't need the Unnamed column or the id column as these are all unique identifiers and don't provide any information

beers.drop(columns=(['Unnamed: 0','id']), inplace=True)
beers.head()
# Out:
#      abv  ibu                 name                           style  \
# 0  0.050  NaN             Pub Beer             American Pale Lager
# 1  0.066  NaN          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  Rise of the Phoenix                    American IPA
# 3  0.090  NaN             Sinister  American Double / Imperial IPA
# 4  0.075  NaN        Sex and Candy                    American IPA
#
#    brewery_id  ounces
# 0         408    12.0
# 1         177    12.0
# 2         177    12.0
# 3         177    12.0
# 4         177    12.0

# %%
# We want to make sure to drop any duplicate rows

beers.drop_duplicates(inplace=True)
beers.head()
# Out:
#      abv  ibu                 name                           style  \
# 0  0.050  NaN             Pub Beer             American Pale Lager
# 1  0.066  NaN          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  Rise of the Phoenix                    American IPA
# 3  0.090  NaN             Sinister  American Double / Imperial IPA
# 4  0.075  NaN        Sex and Candy                    American IPA
#
#    brewery_id  ounces
# 0         408    12.0
# 1         177    12.0
# 2         177    12.0
# 3         177    12.0
# 4         177    12.0

# %%
beers.abv.isnull().sum()
# Out:
# 62

# %% [markdown]
# There are 62 beers that are missing values for the ABV. The easiest option would be to drop them, but I want to be sure there isn't a pattern to the beers that are missing the ABV; that is, I want to make sure I don't skew the data by removing these beers. Let's take a look at them.

# %%
beers[beers.abv.isnull()]
# Out:
#       abv  ibu                                    name  \
# 294   NaN  NaN                     Double Play Pilsner
# 299   NaN  NaN  N Street Drive-In 50th Anniversary IPA
# 315   NaN  NaN                         Professor Black
# 316   NaN  NaN                             Little Boss
# 317   NaN  NaN                              Van Dayum!
# 318   NaN  NaN                           Spirit Animal
# 407   NaN  NaN                              Fat Paczki
# 408   NaN  NaN                      Earth-Like Planets
# 450   NaN  NaN                          Tampa Pale Ale
# 451   NaN  NaN                  Orange Grove Wheat Ale
# 464   NaN  NaN                    Roler Bock (Current)
# 520   NaN  NaN                        THP White (2006)
# 521   NaN  NaN                        THP Amber (2006)
# 522   NaN  NaN                        THP Light (2006)
# 523   NaN  NaN                         THP Dark (2006)
# 541   NaN  NaN                       Supper Club Lager
# 566   NaN  NaN                         Special Release
# 655   NaN  NaN          WinterWonderGrass Festival Ale
# 656   NaN  NaN                          Boohai Red Ale
# 723   NaN  NaN         Kaleidoscope Collaboration 2012
# 728   NaN  NaN           Dock Street Amber Beer (1992)
# 729   NaN  NaN                Dolores River Hefeweizen
# 730   NaN  NaN                       Dolores River ESB
# 731   NaN  NaN            Snaggletooth Double Pale Ale
# 732   NaN  NaN                  Dolores River Pale Ale
# 733   NaN  NaN                 Dolores River Dry Stout
# 734   NaN  NaN                      Dolores River Mild
# 812   NaN  NaN                      Inclined Plane Ale
# 836   NaN  NaN                           Fort Pitt Ale
# 924   NaN  NaN               Black Iron India Pale Ale
# ...   ...  ...                                     ...
# 1132  NaN  NaN                                 Bastian
# 1167  NaN  NaN                           U. P. Witbier
# 1168  NaN  NaN                  November Gale Pale Ale
# 1169  NaN  NaN              Olde Ore Dock Scottish Ale
# 1170  NaN  NaN                   Widow Maker Black Ale
# 1171  NaN  NaN                   Lift Bridge Brown Ale
# 1172  NaN  NaN                     Pick Axe Blonde Ale
# 1173  NaN  NaN                    Red Jacket Amber Ale
# 1353  NaN  NaN                            AXL Pale Ale
# 1554  NaN  NaN                            The CROWLER™
# 1555  NaN  NaN                    CAN'D AID Foundation
# 1556  NaN  NaN                               Icey.P.A.
# 1558  NaN  NaN                               Birth IPA
# 1636  NaN  NaN           Pete's Wicked Pale Ale (1997)
# 1667  NaN  NaN                           Ponderosa IPA
# 1668  NaN  NaN                        Liquid Amber Ale
# 1714  NaN  NaN                              Rye Porter
# 1719  NaN  NaN                            Miner's Gold
# 1760  NaN  NaN         Cal and Co. Black Cherry Porter
# 1813  NaN  NaN                    Santa Fe Oktoberfest
# 1887  NaN  NaN                     Autumnal Molé Stout
# 1969  NaN  NaN                          Hopluia (2004)
# 2044  NaN  NaN                             30 Min Coma
# 2051  NaN  NaN                  Bourbon Barrel Cowbell
# 2163  NaN  NaN             Manhattan Gold Lager (1990)
# 2186  NaN  NaN                  Cornstalker Dark Wheat
# 2337  NaN  NaN                          West Sixth IPA
# 2345  NaN  NaN                             Royal Lager
# 2347  NaN  NaN                        O’Malley’s Stout
# 2349  NaN  NaN        O’Malley’s Irish Style Cream Ale
#
#                                     style  brewery_id  ounces
# 294                      American Pilsner         380    12.0
# 299        American Double / Imperial IPA         380    12.0
# 315                        American Stout          77    12.0
# 316               American Pale Wheat Ale          77    12.0
# 317              American Amber / Red Ale          77    12.0
# 318               American Pale Ale (APA)          77    12.0
# 407                      Belgian Dark Ale          10    16.0
# 408                      Belgian Pale Ale          10    16.0
# 450               American Pale Ale (APA)         467    12.0
# 451               American Pale Wheat Ale         467    12.0
# 464                 Maibock / Helles Bock         530    16.0
# 520                               Witbier         497    12.0
# 521              American Amber / Red Ale         497    12.0
# 522                   American Blonde Ale         497    12.0
# 523                 English Dark Mild Ale         497    12.0
# 541                   American Pale Lager         192    12.0
# 566                                   NaN          29    16.0
# 655              American Amber / Red Ale          63    12.0
# 656              American Amber / Red Ale          63    12.0
# 723                    American Black Ale         491    16.0
# 728              American Amber / Red Ale         488    12.0
# 729                            Hefeweizen         531    16.0
# 730   Extra Special / Strong Bitter (ESB)         531    16.0
# 731        American Double / Imperial IPA         531    16.0
# 732               American Pale Ale (APA)         531    16.0
# 733                       Irish Dry Stout         531    16.0
# 734                 English Dark Mild Ale         531    16.0
# 812                          American IPA         532    12.0
# 836              American Amber / Red Ale         151    12.0
# 924                          American IPA         536    12.0
# ...                                   ...         ...     ...
# 1132                  American Strong Ale          32    12.0
# 1167                              Witbier          84    12.0
# 1168              American Pale Ale (APA)          84    12.0
# 1169                         Scottish Ale          84    12.0
# 1170                   American Brown Ale          84    12.0
# 1171                   American Brown Ale          84    12.0
# 1172                  American Blonde Ale          84    12.0
# 1173             American Amber / Red Ale          84    12.0
# 1353              American Pale Ale (APA)         440    16.0
# 1554                                  NaN         166    32.0
# 1555                                  NaN         166    12.0
# 1556                         American IPA         166    16.0
# 1558                         American IPA         166    12.0
# 1636              American Pale Ale (APA)         470    12.0
# 1667                         American IPA         548    12.0
# 1668             American Amber / Red Ale         548    12.0
# 1714                      American Porter         386    16.0
# 1719                  American Blonde Ale         386    12.0
# 1760                      American Porter         229    16.0
# 1813                 Märzen / Oktoberfest         392    12.0
# 1887                       American Stout         264    12.0
# 1969         English India Pale Ale (IPA)         508    16.0
# 2044                          Belgian IPA          25    16.0
# 2051                      American Porter          25    16.0
# 2163           American Amber / Red Lager         484    12.0
# 2186              American Dark Wheat Ale         282    12.0
# 2337                         American IPA         100    12.0
# 2345                  American Pale Lager         132    16.0
# 2347                        English Stout         132    12.0
# 2349                            Cream Ale         132    12.0
#
# [62 rows x 6 columns]

# %% [markdown]
# What immediately becomes apparent is that it appears that entire breweries are missing data for the ABV, as most of the breweries appear more than once on this list. However, given the fact that a large range of styles are represented as well as the fact that all of these beers are also missing values for IBU, the best thing to do will be to drop these beers from the data set.

# %%
beers.dropna(subset=['abv'], inplace=True)

# %%
beers.shape
# Out:
# (2315, 6)

# %% [markdown]
# ### Style

# %%
beers[beers['style'].isnull()]
# Out:
#        abv   ibu                            name style  brewery_id  ounces
# 853  0.060  21.0  Kilt Lifter Scottish-Style Ale   NaN         160    12.0
# 866  0.053  27.0                   OktoberFiesta   NaN          66    12.0

# %% [markdown]
# Since these two rows are only missing style and nothing else, I will impute with the style that makes the most sense. The first once is a Scottish Ale, and the second can sensibly be considered an Octoberfest beer.

# %%
beers['style'][853]='Scottish Ale'
beers['style'][866]='Märzen / Oktoberfest'
# Out:
# C:\Users\jimij\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\jimij\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
beers['style'].value_counts().head(10)
# Out:
# American IPA                      412
# American Pale Ale (APA)           236
# American Amber / Red Ale          125
# American Blonde Ale               104
# American Double / Imperial IPA    101
# American Pale Wheat Ale            83
# American Brown Ale                 68
# American Porter                    65
# Saison / Farmhouse Ale             52
# Fruit / Vegetable Beer             48
# Name: style, dtype: int64

# %%
plot=beers['style'].value_counts().plot(kind='bar', figsize=(28,10))
plot.set_title('Number of Beers of each Style', fontsize=35);

# %%
plot2=beers.groupby('style').abv.mean().plot(kind='bar', figsize=(28,10))
plot2.set_title('Average ABV by Beer Style', fontsize=35)
plot2.set_xlabel('')
# Out:
# Text(0.5,0,'')

# %% [markdown]
# Looking at this graph, we can see that certain styles of beer stand out, and we can pull out keywords that are associated with a higher ABV, such as "Imperial" and "Barleywine". We can also see the emergence of the "Low Alcohol Beer" category, which is a major outlier, but of course it is the very cause of the ABV, so there's no reason to do anything about it. Clearly when predicting the ABV of a beer that is labeled low alcohol, you know what to expect!

# %% [markdown]
# ### IBU

# %% [markdown]
# The IBU column has a lot of data missing, but based on what I know about beer, my hypothesis is that IBU and ABV are highly corrolated, so it wouldn't be wise to throw out that column. First, I'll test my hypothesis.

# %%
beers[['abv', 'ibu']].corr()
# Out:
#           abv       ibu
# abv  1.000000  0.668108
# ibu  0.668108  1.000000

# %% [markdown]
# The corrolation coefficient is .668, which is definitely high enough to warrant not throwing out. Therefore, I will impute the IBU by taking the median IBU of the corresponding style of beer, since that is the only other data we have that is related to IBU.

# %%
beers.dropna().head(10)
# Out:
#       abv   ibu                                         name  \
# 14  0.061  60.0                                 Bitter Bitch
# 21  0.099  92.0                                Lower De Boom
# 22  0.079  45.0                                Fireside Chat
# 24  0.044  42.0                              Bitter American
# 25  0.049  17.0         Hell or High Watermelon Wheat (2009)
# 27  0.049  17.0  21st Amendment Watermelon Wheat Beer (2006)
# 28  0.070  70.0                    21st Amendment IPA (2006)
# 29  0.070  70.0                 Brew Free! or Die IPA (2008)
# 30  0.070  70.0                 Brew Free! or Die IPA (2009)
# 31  0.085  52.0         Special Edition: Allies Win The War!
#
#                       style  brewery_id  ounces
# 14  American Pale Ale (APA)         177    12.0
# 21      American Barleywine         368     8.4
# 22            Winter Warmer         368    12.0
# 24  American Pale Ale (APA)         368    12.0
# 25   Fruit / Vegetable Beer         368    12.0
# 27   Fruit / Vegetable Beer         368    12.0
# 28             American IPA         368    12.0
# 29             American IPA         368    12.0
# 30             American IPA         368    12.0
# 31       English Strong Ale         368    12.0

# %%
ibu_by_style=beers.groupby('style').ibu.mean()
ibu_by_style
# Out:
# style
# Abbey Single Ale                      22.000000
# Altbier                               33.285714
# American Adjunct Lager                11.200000
# American Amber / Red Ale              36.298701
# American Amber / Red Lager            23.600000
# American Barleywine                   96.000000
# American Black Ale                    68.900000
# American Blonde Ale                   20.983607
# American Brown Ale                    29.894737
# American Dark Wheat Ale               27.600000
# American Double / Imperial IPA        92.863014
# American Double / Imperial Pilsner    85.000000
# American Double / Imperial Stout      62.000000
# American IPA                          67.468013
# American India Pale Lager             63.333333
# American Malt Liquor                        NaN
# American Pale Ale (APA)               44.675497
# American Pale Lager                   26.750000
# American Pale Wheat Ale               20.979592
# American Pilsner                      23.285714
# American Porter                       31.923077
# American Stout                        41.312500
# American Strong Ale                   65.416667
# American White IPA                    48.833333
# American Wild Ale                     27.000000
# Baltic Porter                         54.000000
# Belgian Dark Ale                      29.666667
# Belgian IPA                           57.000000
# Belgian Pale Ale                      23.875000
# Belgian Strong Dark Ale               72.000000
#                                         ...
# Kölsch                                21.777778
# Light Lager                           11.666667
# Low Alcohol Beer                            NaN
# Maibock / Helles Bock                 27.500000
# Mead                                        NaN
# Milk / Sweet Stout                    25.166667
# Munich Dunkel Lager                   20.333333
# Munich Helles Lager                   17.916667
# Märzen / Oktoberfest                  23.090909
# Oatmeal Stout                         29.600000
# Old Ale                               40.000000
# Other                                 16.000000
# Pumpkin Ale                           24.818182
# Quadrupel (Quad)                      24.000000
# Radler                                19.666667
# Rauchbier                                   NaN
# Roggenbier                            20.000000
# Russian Imperial Stout                86.500000
# Rye Beer                              52.000000
# Saison / Farmhouse Ale                28.391304
# Schwarzbier                           31.000000
# Scotch Ale / Wee Heavy                24.230769
# Scottish Ale                          26.416667
# Shandy                                      NaN
# Smoked Beer                           35.000000
# Tripel                                23.500000
# Vienna Lager                          24.083333
# Wheat Ale                             24.000000
# Winter Warmer                         24.625000
# Witbier                               16.208333
# Name: ibu, Length: 99, dtype: float64

# %% [markdown]
# There are some styles that have no IBU data at all to use, so I will have to find another way to deal with those.

# %%
ibu_by_style[ibu_by_style.isnull()]
# Out:
# style
# American Malt Liquor   NaN
# Braggot                NaN
# Cider                  NaN
# Flanders Red Ale       NaN
# Kristalweizen          NaN
# Low Alcohol Beer       NaN
# Mead                   NaN
# Rauchbier              NaN
# Shandy                 NaN
# Name: ibu, dtype: float64

# %% [markdown]
# Thankfully this list is small enough that I can do some research to figure out what to do with each category.

# %%
beers[beers['style']=='American Malt Liquor']
# Out:
#         abv  ibu                  name                 style  brewery_id  \
# 1361  0.099  NaN  Axe Head Malt Liquor  American Malt Liquor         134
#
#       ounces
# 1361    24.0

# %% [markdown]
# Since this is the only malt liquor on the list and there's no IBU data that I could find for it, the IBU isn't very important. Other malt liquors I was able to find had IBUs of 25-45, so I will impute it as 35.

# %%
beers.loc[1361,'ibu']=35

# %%
beers[beers['style']=='Braggot']
# Out:
#         abv  ibu                     name    style  brewery_id  ounces
# 2185  0.075  NaN  Golden Frau Honey Wheat  Braggot         282    12.0

# %% [markdown]
# According to my research, this beer is often considered an American Pale Wheat Ale, so I will relabel it as that since we have more data on that style of beer. I also found that is has an IBU of 12, so I will fill that in as well.

# %%
beers.loc[2185,'style']='American Pale Wheat Ale'
beers.loc[2185,'ibu']=12

# %%
beers[beers['style']=='Cider'].head()
# Out:
#       abv  ibu                        name  style  brewery_id  ounces
# 15   0.06  NaN                 Ginja Ninja  Cider         154    12.0
# 16   0.06  NaN               Cherried Away  Cider         154    12.0
# 17   0.06  NaN                Rhubarbarian  Cider         154    12.0
# 18   0.06  NaN                 BrightCider  Cider         154    12.0
# 122  0.05  NaN  Angry Orchard Apple Ginger  Cider         434    16.0

# %% [markdown]
# IBU doesn't apply to cider, so I will impute these as 0.

# %%
beers.loc[beers['style']=='Cider','ibu']=0

# %%
beers[beers['style']=='Flanders Red Ale']
# Out:
#         abv  ibu            name             style  brewery_id  ounces
# 1036  0.083  NaN  Southern Cross  Flanders Red Ale         204    19.2

# %% [markdown]
# I was able to find the IBU of this beer, so I will fill that in.

# %%
beers.loc[1036,'ibu']=59

# %%
beers[beers['style']=='Kristalweizen']
# Out:
#        abv  ibu              name          style  brewery_id  ounces
# 791  0.045  NaN  Weiss Weiss Baby  Kristalweizen          36    12.0

# %% [markdown]
# Same as above, I will fill in the IBU I found.

# %%
beers.loc[791,'ibu']=40

# %%
beers[beers['style']=='Low Alcohol Beer']
# Out:
#         abv  ibu         name             style  brewery_id  ounces
# 2266  0.001  NaN  Scotty K NA  Low Alcohol Beer         522    16.0

# %% [markdown]
# As stated above, low alcohol beers will intrinsically have an ABV of pratically 0, so I will just impute 0 for the IBU as well.

# %%
beers.loc[2266,'ibu']=0

# %%
beers[beers['style']=='Mead']
# Out:
#         abv  ibu                    name style  brewery_id  ounces
# 307   0.059  NaN           Yellow Collar  Mead         422    12.0
# 308   0.059  NaN            Green Collar  Mead         422    12.0
# 1702  0.080  NaN      Nectar of the Hops  Mead         421    16.0
# 1703  0.080  NaN         Sunshine Nectar  Mead         421    16.0
# 1704  0.080  NaN  Black Raspberry Nectar  Mead         421    16.0

# %% [markdown]
# As with ciders, mead doesn't have an IBU.

# %%
beers.loc[beers['style']=='Mead','ibu']=0

# %%
beers[beers['style']=='Rauchbier']
# Out:
#        abv  ibu              name      style  brewery_id  ounces
# 392  0.070  NaN  Beasts A'Burnin'  Rauchbier          10    16.0
# 413  0.051  NaN       Smoky Wheat  Rauchbier          10    16.0

# %% [markdown]
# I couldn't find any IBU information for these beers, but rauchbiers in general have an IBU of 20-30, so I will use 25.

# %%
beers.loc[beers['style']=='Rauchbier','ibu']=25

# %%
beers[beers['style']=='Shandy']
# Out:
#         abv  ibu                     name   style  brewery_id  ounces
# 1289  0.042  NaN           Saranac Shandy  Shandy         299    12.0
# 2168  0.044  NaN  Curious Traveler Shandy  Shandy         334    12.0
# 2205  0.050  NaN        Big Island Shandy  Shandy         474    16.0

# %% [markdown]
# I couldn't find any IBU information for any of these, so I will just impute 0.

# %%
beers.loc[beers['style']=='Shandy','ibu']=0

# %%
# Now I will impute each missing IBU value with the mean of its corresponding style

beers.ibu = beers.groupby('style')['ibu'].transform(lambda x: x.fillna(x.mean()))

# %%
beers.head()
# Out:
#      abv        ibu                 name                           style  \
# 0  0.050  26.750000             Pub Beer             American Pale Lager
# 1  0.066  44.675497          Devil's Cup         American Pale Ale (APA)
# 2  0.071  67.468013  Rise of the Phoenix                    American IPA
# 3  0.090  92.863014             Sinister  American Double / Imperial IPA
# 4  0.075  67.468013        Sex and Candy                    American IPA
#
#    brewery_id  ounces
# 0         408    12.0
# 1         177    12.0
# 2         177    12.0
# 3         177    12.0
# 4         177    12.0

# %% [markdown]
# Now the IBU column is completely filled in. Let's check and make sure there are no remaining null values.

# %%
beers.isnull().sum()
# Out:
# abv           0
# ibu           0
# name          0
# style         0
# brewery_id    0
# ounces        0
# dtype: int64

# %% [markdown]
# ### Brewery Location

# %%
beers.brewery_id.value_counts().head(10)
# Out:
# 10     60
# 25     36
# 166    27
# 141    25
# 46     24
# 131    21
# 165    20
# 107    19
# 368    19
# 30     19
# Name: brewery_id, dtype: int64

# %%
breweries=pd.read_csv('breweries.csv')

# %%
breweries.head()
# Out:
#    Unnamed: 0                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
breweries.drop(columns='Unnamed: 0', inplace=True)

# %%
breweries.head()
# Out:
#                         name           city state
# 0         NorthGate Brewing     Minneapolis    MN
# 1  Against the Grain Brewery     Louisville    KY
# 2   Jack's Abby Craft Lagers     Framingham    MA
# 3  Mike Hess Brewing Company      San Diego    CA
# 4    Fort Point Beer Company  San Francisco    CA

# %%
breweries.state.value_counts()
# Out:
#  CO    47
#  CA    39
#  MI    32
#  OR    29
#  TX    28
#  PA    25
#  MA    23
#  WA    23
#  IN    22
#  WI    20
#  NC    19
#  IL    18
#  NY    16
#  VA    16
#  OH    15
#  FL    15
#  MN    12
#  AZ    11
#  VT    10
#  MO     9
#  MT     9
#  ME     9
#  CT     8
#  GA     7
#  MD     7
#  AK     7
#  OK     6
#  RI     5
#  NE     5
#  IA     5
#  ID     5
#  LA     5
#  KY     4
#  NM     4
#  SC     4
#  WY     4
#  UT     4
#  HI     4
#  KS     3
#  TN     3
#  NJ     3
#  NH     3
#  AL     3
#  NV     2
#  DE     2
#  MS     2
#  AR     2
#  DC     1
#  ND     1
#  WV     1
#  SD     1
# Name: state, dtype: int64

# %% [markdown]
# Now I will take the city and state of each brewery and put it in my beers dataframe so that I can gain insight about the beers based on location.

# %%
# I will do a .loc search where the rows are the brewery_id in the "beers" dataframe, which corresponds to the index of the
# "breweries" dataframe, and the column is either city or state, then by resetting the index, it will match up with the index of
# the "beers" dataframe, allowing me to add on a new column.

beer_cities=breweries.loc[beers.brewery_id,'city'].reset_index(drop=True)
beer_states=breweries.loc[beers.brewery_id,'state'].reset_index(drop=True)

# %%
beers['city']=beer_cities
beers['state']=beer_states
beers.head()
# Out:
#      abv        ibu                 name                           style  \
# 0  0.050  26.750000             Pub Beer             American Pale Lager
# 1  0.066  44.675497          Devil's Cup         American Pale Ale (APA)
# 2  0.071  67.468013  Rise of the Phoenix                    American IPA
# 3  0.090  92.863014             Sinister  American Double / Imperial IPA
# 4  0.075  67.468013        Sex and Candy                    American IPA
#
#    brewery_id  ounces  city state
# 0         408    12.0  Bend    OR
# 1         177    12.0  Gary    IN
# 2         177    12.0  Gary    IN
# 3         177    12.0  Gary    IN
# 4         177    12.0  Gary    IN

# %%
plot=beers.groupby('state').abv.mean().plot(kind='bar', figsize=(28,10))
plot.set_title('Average ABV by State', fontsize=35)
plot.set_xlabel('')
# Out:
# Text(0.5,0,'')

# %% [markdown]
# This is obviously a bit misleading since many states have a very small sample size. Nevertheless, we can do some more exploring to figure out why these discrepencies exist. To start, we can look at the most common beer style by state to gain some insights.

# %%
# I grouped beers by state and found the top style for each state

top_styles=beers.groupby('state')['style'].describe()['top']
top_styles
# Out:
# state
#  AK     American Pale Ale (APA)
#  AL                American IPA
#  AR    American Amber / Red Ale
#  AZ                American IPA
#  CA                American IPA
#  CO                American IPA
#  CT                American IPA
#  DC     Belgian Strong Pale Ale
#  DE                American IPA
#  FL                American IPA
#  GA     American Pale Wheat Ale
#  HI     American Pale Ale (APA)
#  IA     American Pale Ale (APA)
#  ID                American IPA
#  IL     American Pale Ale (APA)
#  IN                American IPA
#  KS     American Pale Ale (APA)
#  KY                American IPA
#  LA                American IPA
#  MA                American IPA
#  MD                American IPA
#  ME     American Pale Ale (APA)
#  MI                American IPA
#  MN                American IPA
#  MO                American IPA
#  MS     American Pale Wheat Ale
#  MT                American IPA
#  NC                American IPA
#  ND                       Cider
#  NE                American IPA
#  NH     American Pale Ale (APA)
#  NJ         American Blonde Ale
#  NM                American IPA
#  NV    American Amber / Red Ale
#  NY     American Pale Ale (APA)
#  OH                American IPA
#  OK                American IPA
#  OR                American IPA
#  PA                American IPA
#  RI         American Pale Lager
#  SC     American Pale Wheat Ale
#  SD    American Amber / Red Ale
#  TN                Vienna Lager
#  TX                American IPA
#  UT     American Pale Ale (APA)
#  VA                American IPA
#  VT                American IPA
#  WA                American IPA
#  WI     American Pale Ale (APA)
#  WV             American Porter
#  WY      Saison / Farmhouse Ale
# Name: top, dtype: object

# %%
top_styles.value_counts()
# Out:
# American IPA                28
# American Pale Ale (APA)     10
# American Pale Wheat Ale      3
# American Amber / Red Ale     3
# Belgian Strong Pale Ale      1
# American Porter              1
# Saison / Farmhouse Ale       1
# Vienna Lager                 1
# American Blonde Ale          1
# American Pale Lager          1
# Cider                        1
# Name: top, dtype: int64

# %%
plot2=beers.groupby('state')['style'].value_counts().index[0].plot(kind='bar', figsize=(28,10))
plot2.set_title('Most Common Beer Style by State', fontsize=35)
plot2.set_xlabel('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-417-8cfcc6dfd503> in <module>()
# ----> 1 plot2=beers.groupby('state')['style'].value_counts().index[0].plot(kind='bar', figsize=(28,10))
#       2 plot2.set_title('Most Common Beer Style by State', fontsize=35)
#       3 plot2.set_xlabel('')
#
# AttributeError: 'tuple' object has no attribute 'plot'
